# %%
import csv

# Fixed parameters
a = 2.2
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# List of frequencies and axial ratios
frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]
axial_ratios = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]

# File path
file_path = 'parameters.csv'

# Writing to the CSV file
with open(file_path, 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write header row
    csv_writer.writerow(['Frequency', 'a', 'b', 'c', 'w', 'h2', 'μ', 'τ', 'Axial Ratio'])
    
    # Write rows with one-to-one mapping of frequency and axial ratio
    for freq, axial_ratio in zip(frequencies, axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("CSV file created successfully.")
# Out:
# CSV file created successfully.

# %%
import csv

# Fixed parameters
a = 1.8
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]
 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 38.570957, 30.141973, 20.639379, 14.212892, 7.3830578, 7.1555546, 
4.1040477, 4.1979915, 16.686116, 3.4774396, 1.9348732, 2.3116034, 2.3536719, 1.4569303, 
1.3562865, 1.7380306, 2.5595677, 3.4715583, 4.0276327, 7.7137097, 5.7653179, 6.1721564, 
7.8191295, 13.364588, 19.568783]
  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 2
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]

 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 37.868861, 29.366899, 19.703361, 17.604883, 7.6615768, 7.4417766, 
4.4968526, 3.1112246, 29.433996, 4.9162745, 1.899351, 1.6700559, 1.5455726, 1.3213118, 
1.224707, 1.5579549, 2.4002778, 3.4110711, 3.9958162, 6.5940547, 6.8329628, 4.1909411, 
13.475291, 10.839686, 17.678623]

  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 2.4
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]


 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 36.799811, 28.178356, 18.263855, 40, 8.0966574, 7.8594665, 5.1568334, 
1.5782218, 14.318365, 9.3198807, 3.6008335, 1.8882499, 1.4015625, 1.3249914, 1.1991118, 
0.67475743, 1.4771565, 3.0858391, 4.5756111, 5.4789141, 7.3672203, 7.6421594, 5.459256, 
13.152447, 11.903104]


  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 2.6
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 36.183337, 27.463921, 17.369775, 19.892994, 8.2808833, 7.9763342, 
5.334757, 1.4086703, 11.267483, 12.053001, 4.8887259, 2.8289322, 2.2528756, 2.1465012, 
2.0805485, 1.280588, 1.1702592, 2.8016916, 4.5082842, 5.7111657, 6.1556417, 8.7042137, 
5.9356892, 24.978244, 9.8184802]



  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.4
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 39.726004, 31.460901, 22.253766, 12.591254, 7.0324214, 6.5893552, 
3.4354747, 7.0330914, 9.0331222, 2.6163485, 3.47177, 4.0058118, 3.655695, 3.1995489, 
2.8973607, 2.9466056, 3.2531141, 3.377654, 5.8619261, 5.4160399, 8.9678189, 3.9140576, 
15.60883, 21.388383, 26.661009]



  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.6
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 39.288178, 30.965859, 21.639208, 12.859089, 7.1966596, 6.9270445, 
3.8504785, 5.1256118, 12.647984, 2.6513701, 2.3141119, 2.7982655, 2.6497196, 2.2427874, 
2.0291801, 2.2572836, 2.8519116, 3.4255631, 4.6850489, 9.5638722, 6.7220237, 18.660991, 
9.5147633, 17.06785, 22.903603]




  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.8
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 38.513743, 30.256514, 21.066122, 11.87232, 6.6984767, 
6.5072836, 3.945868, 3.2605006, 23.833688, 4.0453397, 2.3026576, 
3.2586985, 3.9830817, 4.7691976, 2.9433214, 3.877216, 5.2119889, 
6.7839477, 8.3048763, 9.7394467, 10.441256, 9.7984915, 6.8487509, 
14.361641, 16.537931]





  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.8
b =
# Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.8
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 0.8

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 38.806653, 30.401672, 21.121001, 20.197976,
8.6547846, 7.6648622, 4.3546756, 5.0830579, 14.829784,
3.6709172, 2.1048508, 1.9232418, 1.5717054, 0.89895796,
0.49074549, 0.40327054, 0.94877598, 1.7216749, 3.9919837,
10.145085, 6.122374, 37.087889, 9.6618941, 14.979893, 20.374337]














  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.8
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.0

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 37.261322, 28.719328, 18.941263, 23.937627,
7.9818863, 7.8248919, 5.0983064, 1.8434018, 17.831433, 7.5376856,
2.6854644, 1.3453921, 0.97416088, 0.90441024, 0.7167981, 0.69244634,
1.6820434, 3.0071141, 4.0574103, 4.6193902, 8.6474617, 6.1182863,
10.653806, 7.9664049, 14.725923]















  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.8
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.2

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 38.704414, 30.158615, 20.310901, 13.86517,
7.3373713, 7.3611496, 4.0695025, 4.7272514, 13.808392, 2.863721,
1.4520616, 1.5852939, 1.42661, 0.68664079, 0.31809028, 0.29729708,
0.80533702, 1.3239424, 3.4479056, 12.623554, 4.9344658, 24.92555,
7.8586966, 14.453833, 20.114795]
















  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import csv

# Fixed parameters
a = 1.8
b = 2
c = 0.2
w = 8
h2 = 12
μ = 0.8
τ = 1.4

# New values for frequency and axial ratio
new_frequencies = [0.17241379, 0.34482759, 0.51724138, 0.68965517, 0.86206897, 1.0344828, 1.2068966, 
1.3793103, 1.5517241, 1.7241379, 1.8965517, 2.0689655, 2.2413793, 2.4137931, 2.5862069, 
2.7586207, 2.9310345, 3.1034483, 3.2758621, 3.4482759, 3.6206897, 3.7931034, 3.9655172, 
4.137931, 4.3103448, 4.4827586, 4.6551724, 4.8275862, 5]



 # Example new frequencies
new_axial_ratios = [40, 40, 40, 40, 38.681876, 30.106223, 20.131551, 12.02885,
7.0025382, 7.2942461, 4.0071003, 4.6471042, 13.590923, 2.6655699,
1.2779776, 1.5068195, 1.4080156, 0.6320745, 0.27459007, 0.27325807,
0.77184595, 1.2177319, 3.302583, 13.905152, 4.6836069, 20.148912,
7.3600258, 14.323529, 20.052943]

















  # Example new axial ratios

# Existing CSV file path
file_path = 'parameters.csv'

# Append new rows to the existing CSV file
with open(file_path, 'a', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write new rows for each combination of frequency and axial ratio
    for freq, axial_ratio in zip(new_frequencies, new_axial_ratios):
        csv_writer.writerow([freq, a, b, c, w, h2, μ, τ, axial_ratio])

print("New values added to the existing CSV file successfully.")
# Out:
# New values added to the existing CSV file successfully.

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('parameters.csv')

# Define the columns to check for duplicates
duplicate_cols = ['Frequency', 'a', 'b', 'c', 'w', 'h2', 'μ', 'τ', 'Axial Ratio']

# Drop duplicate rows based on specified columns
df_unique = df.drop_duplicates(subset=duplicate_cols)

# Write the updated DataFrame to a new CSV file
df_unique.to_csv('parameters_unique.csv', index=False)

print("Duplicate rows merged successfully.")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the unique parameters CSV file
df_unique = pd.read_csv('parameters_unique.csv')

# Plot frequency against axial ratio
plt.figure(figsize=(10, 6))
plt.plot(df_unique['Frequency'], df_unique['Axial Ratio'], marker='o', linestyle='-', color='b')
plt.axhline(y=3.0, color='r', linestyle='--', label='Axial Ratio = 3.0')
plt.xlabel('Frequency / THz')
plt.ylabel('Axial Ratio')
plt.title('Frequency vs Axial Ratio')
plt.ylim(2, 5)  # Set y-axis limits
plt.legend()
plt.grid(True)
plt.show()

# %%
# Filter rows with axial ratio near or equal to 3
filtered_rows = df_unique[(df_unique['Axial Ratio'] >= 2.9) & (df_unique['Axial Ratio'] <= 3)]

# Sort the filtered rows by frequency in ascending order
sorted_filtered_rows = filtered_rows.sort_values(by='Frequency')

# Initialize an empty list to store bandwidths and corresponding rows
bandwidth_rows = []

# Calculate bandwidth for each pair of consecutive frequencies
for i in range(len(sorted_filtered_rows) - 1):
    index1 = sorted_filtered_rows.index[i]
    index2 = sorted_filtered_rows.index[i + 1]
    freq1 = "{:.7f}".format(sorted_filtered_rows.iloc[i]['Frequency'])
    freq2 = "{:.7f}".format(sorted_filtered_rows.iloc[i + 1]['Frequency'])
    bandwidth = 2 * (float(freq2) - float(freq1)) / (float(freq2) + float(freq1))
    bandwidth_rows.append((index1, index2, freq1, freq2, bandwidth))

# Create a DataFrame from the bandwidth_rows list
bandwidth_df = pd.DataFrame(bandwidth_rows, columns=['Index 1', 'Index 2', 'Frequency 1', 'Frequency 2', 'Bandwidth'])

# Display the sorted DataFrame
sorted_bandwidth_df = bandwidth_df.sort_values(by='Frequency 1')
print(sorted_bandwidth_df)
# Out:
#    Index 1  Index 2 Frequency 1 Frequency 2  Bandwidth
# 0       16      386   2.9310345   3.1034483   0.057143
# 1      386      217   3.1034483   3.2758621   0.054054
# 2      217      304   3.2758621   3.2758621   0.000000
# 3      304      387   3.2758621   3.2758621   0.000000
# 4      387      164   3.2758621   3.4482759   0.051282
# 5      164      588   3.4482759   3.6206897   0.048780
# 6      588      704   3.6206897   3.6206897   0.000000
# 7      704      531   3.6206897   3.7931034   0.046512
# 8      531      647   3.7931034   3.7931034   0.000000

# %%
# Find the row with maximum bandwidth
max_bandwidth_row = sorted_bandwidth_df.loc[sorted_bandwidth_df['Bandwidth'].idxmax()]

# Create a DataFrame with only the row with maximum bandwidth
max_bandwidth_table = pd.DataFrame([max_bandwidth_row], columns=sorted_bandwidth_df.columns)

# Display the table
print(max_bandwidth_table)
# Out:
#    Index 1  Index 2 Frequency 1 Frequency 2  Bandwidth
# 0       16      386   2.9310345   3.1034483   0.057143

# %%
# Extract rows with index 16 and 386
rows = df_unique.loc[[16, 386]]

# Display the rows in table format
print(rows)
# Out:
#      Frequency    a    b    c    w  h2    μ    τ  Axial Ratio
# 16    2.931034  2.2  2.0  0.2  8.0  12  0.8  1.0     2.931034
# 386   3.103448  1.8  2.0  0.1  8.0  12  0.8  1.0     2.977024
